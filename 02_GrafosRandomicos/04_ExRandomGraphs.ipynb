# %% [markdown]
# # Exemplos de Grafos Randômicos

# %%
import networkx as nx
from networkx.algorithms import bipartite

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
er = nx.erdos_renyi_graph(20, 0.15)
nx.draw(er, node_color='g', node_size=800, with_labels=True)

# %%
ws = nx.watts_strogatz_graph(30, 3, 0.1)
nx.draw(ws, node_color='c', node_size=800, with_labels=True)

# %%
plt.figure(figsize=(10,7))
rd = nx.random_lobster(20, 0.9, 0.9)
nx.draw(rd, node_size=800, with_labels=True)
