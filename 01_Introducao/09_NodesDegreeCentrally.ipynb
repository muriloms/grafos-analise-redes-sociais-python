# %% [markdown]
# # Nodes, Degree e Centralidade

# %%
# Carregar pacotes
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
n = 10 # nodes
m = 20 # edges

G = nx.gnm_random_graph(n,m)

nx.draw(G, with_labels=True)

print("Nodes Degrees Clustering")

for v in nx.nodes(G):
    print('%s %d %f' %(v, nx.degree(G,v), nx.clustering(G,v)))
# Out:
# Nodes Degrees Clustering
# 0 5 0.500000
# 1 3 0.666667
# 2 3 0.666667
# 3 1 0.000000
# 4 6 0.533333
# 5 2 1.000000
# 6 4 0.666667
# 7 5 0.500000
# 8 4 0.500000
# 9 7 0.428571
